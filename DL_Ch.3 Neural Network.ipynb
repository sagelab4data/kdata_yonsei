# %% [markdown]
# # 3 . 신경망의 구성

# %% [markdown]
# ## 3.1 퍼셉트론에서 뉴럴네트워크로
# ### 3.1.1 뉴럴네트워크의 예
# ### 3.1.2 퍼셉트론 다시보기
# ### 3.1.3 활성화 함수의 등장

# %% [markdown]
# ## 3.2 활성화 함수

# %% [markdown]
# ### 3.2.1 시그모이드 함수

# %% [markdown]
# ### 3.2.2 스텝함수 구현

# %%
# 3.2.2.1 계단 함수의 구현
def step_function(x) :
    if x > 0 :
        return 1
    else :
        return 0

# %%
# 3.2.2.2 계단 함수 축약형
    ***

# %%
# 3.2.2.3 넘파이의 비교연산 결과
import numpy as np
x= np.array([-1.0, 1.0, 2.0])

y = x > 0
print (y)

y = y.astype(int)
print(y)
# Out:
# [False  True  True]
# [0 1 1]

# %% [markdown]
# ### 3.2.3 스텝함수의 그래프

# %%
# 3.2.3.1  넘파이 배열을 이용한 계단 함수 구현 
import numpy as np

def step_function(x) :
    return np.array(x>0, dtype = int)

# %%
# 3.2.3.2  계단함수 그래프 
import matplotlib.pyplot as plt

x = np.arange(-5.0, 5.0, 0.1)
y = ***

plt.plot(x,y)
plt.title('step')
plt.show()

# %% [markdown]
# ### 3.2.4 시그모이드함수 그리기

# %%
# 3.2.4.1 시그모이드 함수 생성 
def sigmoid(x):
    return ***

# 시그모이드 함수 출력값 확인
x = np.array([-1.0, 1.0, 2.0])
sigmoid(x)
# Out:
# array([0.26894142, 0.73105858, 0.88079708])

# %%
# 3.2.4.2 시그모이드함수  그래프 
x= np.arange(-5.0, 5.0, 0.1)
y= ***

plt.plot(x,y)
plt.title('sigmoid')
plt.show()

# %%
# 3.2.4.3 [참고] 시그모이드함수 공식 요소별 그래프
import matplotlib.pyplot as plt
import numpy as np

# 시그모이드 함수 : 부분 함수 단위로 파악
fig, ax = plt.subplots (2,4,sharex= True,  figsize = (8,4),
                        constrained_layout=True)
fig.suptitle('Sigmoid function : step by step')
#fig.tight_layout()
x = np.arange(-10,10,0.1)

# exp(x)
y1 = np.exp(x)
ax[0,0].plot(x, y1)
ax[0,0].set_title('exp(x)')

# 1+exp(x)
y2 = 1+np.exp(x)
ax[0,1].plot(x, y2)
ax[0,1].set_title('1+exp(x)')

# exp(-x)
y3 = np.exp(-x)
ax[0,2].plot(x, y3)
ax[0,2].set_title('exp(-x)')

# 1+exp(-x)
y4 = 1+np.exp(-x)
ax[0,3].plot(x, y4)
ax[0,3].set_title('1+exp(-x)')

# 1/(np.exp(x))
y5 = 1 / np.exp(x)
ax[1,0].plot(x, y5)
ax[1,0].set_title('1/(np.exp(x))')

# 1/(1+ exp(x))
y6 = 1 / (1 + np.exp(x))
ax[1,1].plot(x, y6)
ax[1,1].set_title('1/(1+exp(x))')

# 1/(np.exp(-x))
y7 = 1 / np.exp(-x)
ax[1,2].plot(x, y7)
ax[1,2].set_title('1/(np.exp(-x))')

# 1/(1+exp(-x))
y8 = 1 / (1+np.exp(-x))
ax[1,3].plot(x, y8)
ax[1,3].set_title('1/(1+exp(-x))')

plt.show()

# %% [markdown]
# ### 3.2.5 시그모이드함수와 스텝함수의 비교

# %%
# 3.2.5.1 시그모이드 함수와 스텝함수의 비교

x= np.arange(-5.0, 5.0, 0.1)
y1 = step_function(x)
y2 = sigmoid(x)

plt.plot(x, y1, ls= '--')
plt.plot(x, y2)
plt.legend (['step','sigmoid'])
plt.title ('sigmoid vs. step')
plt.show()

# %% [markdown]
# ### 3.2.6 비선형함수

# %% [markdown]
# ### 3.2.7 ReLU 함수 (Rectified Linear Unit)

# %%
# 3.2.7.1 ReLU 함수 정의
def relu (x) :
    ***

# %%
# 3.2.7.2 ReLU  그래프 
x= np.arange(-5.0, 5.0, 0.1)
y= ***

plt.plot(x,y)
plt.title('relu')
plt.show()

# %% [markdown]
# ## 3.3 다차원배열의 계산

# %% [markdown]
# ### 3.3.1 다차원배열

# %%
# 3.3.1.1 1차원 배열
import numpy as np
A= np.array([1,2,3,4])
print(A)

# %%
# 3.3.1.2
np.ndim(A) , A.shape

# %%
# 3.3.1.3 2차원 배열
B = np.array([[1,2],[3,4],[5,6]])
print(B)

# %%
# 3.3.1.4
np.ndim(B), B.shape

# %% [markdown]
# ### 3.3.2 행렬의 곱

# %% [markdown]
# #### (2,2) x (2,2) 행렬곱

# %%
# 3.3.2.1 2개의 (2,2) 모양 행렬
A = np.array([[1,2],[3,4]])
B = np.array([[5,6],[7,8]])
A.shape, B.shape

# %%
# 3.3.2.2  행렬곱 수행
***

# %%
# 3.3.2.3  원소끼리 곱하는 일반 * 연산과 다르다. 
***

# %%
# Out:
# [22 28]
# [14 32]
# [[22 28]]
# [[14]
#  [32]]

# %% [markdown]
# #### (3,2) x (2,4) 행렬곱

# %%
# 3.3.2.4 (3,2) 모양의 행렬
A = np.array( *** )
print (A, A.shape)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]] (3, 2)

# %%
# 3.3.2.5 (2,4) 모양의 행렬
B= np.array( *** )
print(B, B.shape)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]] (2, 4)

# %%
# 3.3.2.6 행렬곱 수행
AdotB = ***
print (AdotB, AdotB.shape)
# Out:
# [[11 14 17 20]
#  [23 30 37 44]
#  [35 46 57 68]] (3, 4)

# %% [markdown]
# #### (3,2) x (2,) 행렬곱

# %%
# 3.3.2.7 (3,2), (2) 모양의 행렬
A = np.array([[1,2],[3,4],[5,6]])
B= np.array( *** )
print(B, B.shape)

# %%
# 3.3.2.8 행렬곱
AdotB = ***
print (AdotB, AdotB.shape)

# %% [markdown]
# #### AxC 는 CxA와 같지 않다

# %%
# 3.3.2.9 (3,2), (2,2) 행렬
A = np.array([[1,2],[3,4],[5,6]])
print (A, A.shape)
C = np.array([[1,2],[3,4]])
print (C,C.shape)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]] (3, 2)
# [[1 2]
#  [3 4]] (2, 2)

# %%
# 3.3.2.10 (3,2)(2,2) 는 계산 가능
***
# Out:
# array([[ 7, 10],
#        [15, 22],
#        [23, 34]])

# %%
# 3.3.2.11 (2,2)(3,2) 는 계산 불가
***
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-60485c249d57> in <module>()
#       1 # 3.3.2.11 (2,2)(3,2) 는 계산 불가
# ----> 2 np.dot(C,A)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (2,2) and (3,2) not aligned: 2 (dim 1) != 3 (dim 0)

# %% [markdown]
# ### 3.3.3 신경망에서의 행렬의 곱

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 3.3.3.1  입력값 X
X = np.array([1,2])
X.shape
# Out:
# (2,)

# %%
# 3.3.3.2 가중치 W
W = np.array( ***)
print(W)
# Out:
# [[1 3 5]
#  [2 4 6]]

# %%
# 3.3.3.3  Y =  X dot W 
Y = ***
print(Y)
# Out:
# [ 5 11 17]

# %% [markdown]
# ## 3.4 3층 신경망의 구현

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3.4.1 기호의 확인

# %% [markdown]
# ### 3.4.2 각 층의 신호전달 구현

# %% [markdown]
# #### 1층으로의 전달

# %%
# 3.4.2.1 1층으로 신호전달 (0층 출력 x 1층 가중치 + 1층편향)
X = np.array([ *** )
W1 = np.array( *** )
B1 = np.array(  *** )

print(X.shape)   # (2,)
print(W1.shape)  # (2,3)
print(B1.shape)  # (3,)

A1 = ***
A1
# Out:
# (2,)
# (2, 3)
# (3,)
# array([0.3, 0.7, 1.1])

# %%
# 3.4.2.2 1층 가중치/편향 계산 결과 활성화 함수 통과
Z1 = ***
print (A1)
print (Z1)
# Out:
# [0.3 0.7 1.1]
# [0.57444252 0.66818777 0.75026011]

# %% [markdown]
# #### 2층으로의 전달

# %%
# 3.4.2.3 2층으로 신호전달 (1층 출력 x 2층 가중치 + 2층 편향)
W2 = np.array([[0.1, 0.4],[0.2, 0.5],[0.3, 0.6]])
B2 = np.array([0.1, 0.2])

print (Z1.shape) #(3,)
print (W2.shape) #(3,2)
print (B2.shape) #(2,)

A2 = ***
# Out:
# (3,)
# (3, 2)
# (2,)

# %%
# 3.4.2.4 2층 가중치/편향 계산 결과 활성화 함수 통과
Z2 = ***

print (A2)
print (Z2)

# %% [markdown]
# #### 3층으로의 전달

# %% [markdown]
# ##### identify_function()

# %%
# 3.4.2.5  출력층의 활성화 함수 
def identity_function(x) :
    return x

# %%
# 3.4.2.6 3층으로 신호전달 (2층 출력 x 3층 가중치 + 3층 편향)
W3 = np.array([[0.1,0.3],[0.2,0.4]])
B3 = np.array([0.1, 0.2])

A3 = ***

# %%
# 3.4.2.7 2층 가중치/편향 계산 결과 활성화 함수 (identify_function) 통과
Y = ***
print (A3)
print (Y)

# %% [markdown]
# ### 3.4.3 구현 정리

# %%
# 3.4.3.1  상기 흐름을 구조화

# 가중치와 편향을 생성
def init_network():
    network = {}
    network['W1'] = np.array([[0.1,0.3,0.5],[0.2,0.4,0.6]])
    network['b1'] = np.array([0.1, 0.2, 0.3])
    network['W2'] = np.array([[0.1, 0.4],[0.2, 0.5],[0.3, 0.6]])
    network['b2'] = np.array([0.1, 0.2])
    network['W3'] = np.array([[0.1,0.3],[0.2,0.4]])
    network['b3'] = np.array([0.1, 0.2])
    
    return network

# 행렬 계산을 이용한 신호 전달 수행  ( 입력x가중치+편향  -->  활성화 함수 )
def forward(network, x) :
    W1, W2, W3 = network['W1'], network['W2'], network['W3']
    b1, b2, b3 = network['b1'], network['b2'], network['b3']
    
    a1 = np.dot(x, W1) + b1
    z1 = sigmoid(a1)
    a2 = np.dot(z1,W2) + b2
    z2 = sigmoid(a2)
    a3 = np.dot(z2,W3) + b3
    y = identity_function(a3)
    
    return y

# %%
# 3.4.3.2 함수를 이용한 신경망 신호 전달 구현
network = init_network()
x = np.array([1.0, 0.5])
y = forward(network, x)
print (y)

# %% [markdown]
# ## 3.5 출력층의 설계

# %% [markdown]
# ### 3.5.1 항등함수와 소프트맥스 함수

# %%
# 3.5.1.1 어떤 값들을 정의하고, 해당 값의 지수값을 확인
a = np.array([0.3, 2.9, 4.0])
exp_a = ***  # 지수 함수
print (a)
print (exp_a)
# Out:
# [0.3 2.9 4. ]
# [ 1.34985881 18.17414537 54.59815003]

# %%
# 3.5.1.2 지수로 변환 된값을 합산 (소프트맥스의 분모)
sum_exp_a = ***
sum_exp_a
# Out:
# 74.1221542101633

# %%
# 3.5.1.3 소프트맥스 함수
y = ***  # 지수 함수의 합
y
# Out:
# array([0.01821127, 0.24519181, 0.73659691])

# %% [markdown]
# ##### softmax()

# %%
# 3.5.1.4 소프트맥스 함수의 구현
def softmax(a):
    exp_a= ***
    sum_exp_a = ***
    y = ***
    return y

# %% [markdown]
# ### 3.5.2 소프트맥스 함수의 구현상의 주의사항

# %%
# 3.5.2.1 아주 큰 값으로 소프트맥스 함수값을 구하면...
a = np.array([1010, 1000, 990])
np.exp(a) / np.sum(np.exp(a)) # 소프트맥스 함수
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide
# array([nan, nan, nan])

# %%
# 3.5.2.2  배열 a 에서 최대 원소의 값을 모든 원소에서 뺀다. 
c = np.max(a)  # c = 1010
a-c
# Out:
# array([  0, -10, -20])

# %%
# 3.5.2.3 이 차이값으로 소프트맥스 함수 값을 구해보자. 
np.exp(a-c) / np.sum(np.exp(a-c))
# Out:
# array([9.99954600e-01, 4.53978686e-05, 2.06106005e-09])

# %% [markdown]
# ##### softmax()_revised

# %%
# 3.5.2.4  큰 수 대책이 들어간 소프트맥스 함수
def softmax(a):
    c = np.max(a)
    exp_a= ***
    sum_exp_a = np.sum(exp_a)
    y = exp_a / sum_exp_a
    return y

# %% [markdown]
# ### 3.5.3 소프트맥스함수의 특징

# %%
# 3.5.3.1 소프트맥스 함수의 입력값과 출력값의 크기 순서는 변화하지 않는다. 
a = np.array([0.3, 2.9, 4.0])
y = softmax(a)
y

# %%
# 3.5.3.2  소프트맥스 함수를 통과한 모든 출력값을 합하면 1이 된다. 
***

# %% [markdown]
# ### 3.5.4 출력층의 뉴런 갯수

# %% [markdown]
# ## 3.6 손글씨 숫자인식

# %% [markdown]
# ### 3.6.1 MNIST 데이터셋

# %% [markdown]
# * load_mnist 함수는 저자가 데이터 가공을 위해 제공
# * colab 파이썬 버전과 pickle 라이브러리 버전 이슈로 일부 오류가 있어,  직접 mnist.py를 읽어들여 수행한다.

# %%
# 3.6.1.1 mnist.py 파일을 colab에 업로드
from google.colab import files
src = list(files.upload().values())[0]
# Out:
#      <input type="file" id="files-0b4af178-b6f5-455b-b95e-c38882687d0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b4af178-b6f5-455b-b95e-c38882687d0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mnist.py to mnist (1).py

# %%
# 3.6.1.2 현재 디렉토리에서 mnist.py 내의  load_mnist 함수 import
from *** import ****

# %%
# 3.6.1.3 MNIST 데이터 적재
(x_train, t_train), (x_test, t_test) =\
    load_mnist(flatten = True, normalize = False)

# %%
# 3.6.1.4 MNIST 데이터 형상 확인
print (***.shape)
print (***.shape)
print (***.shape)
print (***.shape)
# Out:
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)

# %% [markdown]
# * 교재에서는 PIL을 이용,  수업에서는 colab 환경을 고려하여 plt.imshow() 이용

# %%
# 3.6.1.5 첫 번째 훈련 데이터의 정답 (레이블) 확인
import numpy as np
import matplotlib.pyplot as plt

label = ***
print(label)
# Out:
# 5

# %%
# 3.6.1.6 첫 번째 훈련 데이터의 형상 확인

img = ***
print(img.shape)         # (784,)

# %%
# 3.6.1.7 첫 번째 훈련 데이터의 형상변경
img = img.reshape(**) # 다시 28x28 형태로
print (img.shape)        # (28, 28)

# %%
# 3.6.1.8 첫 번째 훈련 데이터의 이미지 출력 (plt.imshow() 이용)
***

# %% [markdown]
# ### 3.6.2 신경망의 추론처리

# %% [markdown]
# * 예제에서 사용하는 가중치 업로드
# * 구글 드라이브 마운트 (4장 이후 사용) pickle 버전 관련 오류 발생
# * 본 3장에서는 직접 sample_weight.pkl 파일을 업로드

# %%
# 3.6.2.1 학습된 가중치를 읽어 들인다. 
# sample_weight.pkl 파일을 colab에 업로드
from google.colab import files
src = list(files.upload().values())[0]
# Out:
#      <input type="file" id="files-b2d187f3-b093-49c9-b654-3c09015671d7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b2d187f3-b093-49c9-b654-3c09015671d7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sample_weight.pkl to sample_weight (1).pkl

# %%
# 3.6.2.2 손글씨 분류 추론 수행

import pickle  # 가중치 읽어들일 라이브러리

# get_data() MNIST 데이터 적재하고, 시험 데이터셋을 반환
#  flatten = True : 각 이미지를 1차원 데이터로 변환
#  normalize = True : 검증 성능을 위해 데이터를 0~1로 정규화
#  one_hot_label = False : 정답 레이블은 숫자 형태로 (원-핫 인코딩 X)

def get_data():
    ***

# 학습된 가중치 파일을 읽어 들인다. (앞 부분 network 사전에 해당)
def init_network():
    with open ('sample_weight.pkl', 'rb') as f :
        network = pickle.load(f)
    return network

# predict (network, x) 예측 (입력데이터를 신경망을 통과 시켜 클래스별 확률값 출력)
# 가중치를 매개변수로 부터 변수 지정 (사용편의)
# 0~3층까지 신호 전달
# 은닉층의 활성화 함수 시그모이드,  출력층의 활성화 함수 소프트맥스

def predict(network, x):
    W1, W2, W3 = ***
    b1, b2, b3 = ***
    
    ***
    
    return y

# %%
# 3.6.2.3   시그모이드 함수, 소프트맥스 함수

def sigmoid(x):
    return 1 / (1+np.exp(-x))

def softmax(a):
    c = np.max(a)
    exp_a= np.exp(a-c)
    sum_exp_a = np.sum(exp_a)
    y = exp_a / sum_exp_a
    return y

# %%
# 3.6.2.4 위에서 정의한 함수를 사용하여, MNIST 시험 데이터와 가중치를 적재
# 전체 입력 데이터에 대해서 각각 예측값과 정답레이블을 비교하여 정확도를 구한다. 

# 시험데이터 적재 (10,000개)
x, t = ***

# 학습된 가중치 적재
network = **

# 정확도 측정을 위한 정답 카운터 초기화
accuracy_cnt = 0

for i in range ( *** ) :
    y = ***
    p = np.argmax(y)
    if *** :
        accuracy_cnt +=1

print (f'Accuracy: { accuracy_cnt/len(x) }')
# Out:
# Accuracy:0.9352

# %% [markdown]
# ### 3.6.3 배치처리

# %%
# 3.6.3.1  입력데이터와 가중치의 형상
x, _ = get_data()
network = init_network()
W1, W2, W3 = network['W1'], network['W2'], network['W3']

print ('x:',x.shape)
print ('x[0]:',x[0].shape) 
print ('W1:',W1.shape)
print ('W2:',W2.shape)
print ('W3:',W3.shape)
# Out:
# x: (10000, 784)
# x[0]: (784,)
# W1: (784, 50)
# W2: (50, 100)
# W3: (100, 10)

# %%
# 3.6.3.2 100개씩 묶어서 처리 (대용량이 되었을 때 컴퓨터 구조상의 성능 향상 기대)

# MNIST 데이터 및 학습된 가중치 적재
x, t = get_data()
network = init_network()

# 배치 크기 설정 batch_size 변수, 100개
***  # 묶은 처리 단위

accuracy_cnt = 0

# 100개씩 묶어서 예측 처리
for i in range(0,len(x), batch_size) :

    x_batch = x[i:i+ *** ]
    y_batch = predict(network, *** )
   
    p = np.argmax(y_batch, axis = ***)
    accuracy_cnt += np.sum(p==t[i:i+***])

print (f'Accuracy: { accuracy_cnt/len(x) }')
# Out:
# Accuracy:0.9352

# %%
# 3.6.3.3 np.argmax 예시

x = np.array([[0.1,0.8, 0.1], [0.3,0.1,0.6],
             [0.2,0.5, 0.3], [0.8, 0.1, 0.1]])
y = np.argmax(x , axis =1)
print(y)
# Out:
# [1 2 1 0]

# %%
# 3.6.3.4 두 배열의 비교 예시
y = np.array([1,2,1,0])
t = np.array([1,2,0,0])
print (y==t)
print (np.sum (y==t))
# Out:
# [ True  True False  True]
# 3
